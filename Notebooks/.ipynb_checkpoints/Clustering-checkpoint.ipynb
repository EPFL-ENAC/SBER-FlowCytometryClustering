# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)


from data import *
from helpers import *

# %%
# Automated way to create labeled dataset
#directory='/../data_gated/'
#columns=['FSC-H', 'SSC-H', 'B530-H', 'B572-H', 'B675-H']
#create_labeled_dataset(directory,columns,label_gated=3,label_not_gated=1)

# %%
file = '../labeled_dataset/GL55_DN_3A.csv'
columns=['B530-H', 'B530-A','B675-H','B572-H','Width','FSC-H','SSC-H']
#columns=['FSC-H', 'SSC-H', 'B530-H', 'B675-H','Width']
X,y = preprocess(file,columns)
# Out:
# ../labeled_dataset/GL55_DN_3A.csv

# %%
#run_all_FlowGrid(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
run_all_GMM(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
#run_all_Kmeans(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
#save_all_true(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
run_all_OPTICS(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
run_all_DBSCAN(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
# Out:
# ../labeled_dataset/GL53_UP_3A.csv
# /home/mika/Documents/EPFL/Master/PdS/Notebooks/../labeled_dataset/GL53_UP_3A.csv
# ../labeled_dataset/GL59_DN_2A.csv
# /home/mika/Documents/EPFL/Master/PdS/Notebooks/../labeled_dataset/GL59_DN_2A.csv
# ../labeled_dataset/GL53_UP_1A.csv
# /home/mika/Documents/EPFL/Master/PdS/Notebooks/../labeled_dataset/GL53_UP_1A.csv
# ../labeled_dataset/GL59_DN_3A.csv
# /home/mika/Documents/EPFL/Master/PdS/Notebooks/../labeled_dataset/GL59_DN_3A.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7f450a8cf04c> in <module>
#       3 #run_all_Kmeans(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
#       4 #save_all_true(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
# ----> 5 run_all_OPTICS(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
#       6 run_all_DBSCAN(columns=columns,directory='../labeled_dataset/',output_directory='/outputs/')
#
# ~/Documents/EPFL/Master/PdS/Notebooks/helpers.py in run_all_OPTICS(columns, directory, output_directory)
#     151             X,y = preprocess(directory+filename,columns)
#     152             print(entry.path)
# --> 153             output_labels = clusterOPTICS(X)
#     154             plt.figure()
#     155             pl = sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=output_labels)
#
# ~/Documents/EPFL/Master/PdS/Notebooks/helpers.py in clusterOPTICS(data, metric)
#     274 """
#     275 def clusterOPTICS(data,metric="euclidean"):
# --> 276     assignment = OPTICS(metric=metric).fit(data).labels_
#     277     return assignment
#     278
#
# ~/.local/lib/python3.9/site-packages/sklearn/cluster/_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/cluster/_optics.py in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     493         ordering[ordering_idx] = point
#     494         if core_distances_[point] != np.inf:
# --> 495             _set_reach_dist(core_distances_=core_distances_,
#     496                             reachability_=reachability_,
#     497                             predecessor_=predecessor_,
#
# ~/.local/lib/python3.9/site-packages/sklearn/cluster/_optics.py in _set_reach_dist(core_distances_, reachability_, predecessor_, point_index, processed, X, nbrs, metric, metric_params, p, max_eps)
#     532             # in the dict params
#     533             _params['p'] = p
# --> 534         dists = pairwise_distances(P, np.take(X, unproc, axis=0),
#     535                                    metric=metric, n_jobs=None,
#     536                                    **_params).ravel()
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1788         func = partial(distance.cdist, metric=metric, **kwds)
#    1789
# -> 1790     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1791
#    1792
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     270            [1.41421356]])
#     271     """
# --> 272     X, Y = check_pairwise_arrays(X, Y)
#     273
#     274     # If norms are passed as float32, they are unused. If arrays are passed as
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     144                             estimator=estimator)
#     145     else:
# --> 146         X = check_array(X, accept_sparse=accept_sparse, dtype=dtype,
#     147                         copy=copy, force_all_finite=force_all_finite,
#     148                         estimator=estimator)
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661             try:
#     662                 warnings.simplefilter('error', ComplexWarning)
# --> 663                 if dtype is not None and np.dtype(dtype).kind in 'iu':
#     664                     # Conversion float -> int should not contain NaN or
#     665                     # inf (numpy#14412). We cannot use casting='safe' because
#
# KeyboardInterrupt:

# %%
run_FlowGrid(nbins=2,eps=1.1,isEvaluation=True)

# %%
output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

# %%
print(output_labels.shape)
print(X.shape)
print(y.shape)
# Out:
# (85646,)
# (85646, 7)
# (85647,)

# %%
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=y)
# Out:
# <AxesSubplot:xlabel='B530-H', ylabel='B572-H'>

# %%
#X = X.drop([0])
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=output_labels)
# Out:
# <AxesSubplot:xlabel='B530-H', ylabel='B572-H'>

# %%
from sklearn.metrics.cluster import adjusted_rand_score

adjusted_rand_score(y.drop([0]), output_labels)
# Out:
# 0.10855519616292277

# %%
#Files
file = '../labeled_dataset/GL53_UP_3A.csv'
columns=['FSC-H', 'SSC-H', 'B530-H', 'B572-H', 'B675-H']
df_labeled = pd.read_csv(file)

#creation of X and y
X,y = split_input_output(df_labeled,target_feature='label')

#Detect and remove outliers
X,y = remove_outliers(X,y,contamination=0.03)

#Standardize our data
scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
X[X.columns] = scaler.fit_transform(X[X.columns])

#Save file in csv format
save_to_csv(X,y)

# %%
os.system("python ../FlowGrid/sample_code.py --f fc_data.csv --n 4 --eps 1.1")
output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

# %%
#plot_results_b530_b572(X, columns, assignments=output_labels)
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=y)

# %%
X = X.drop([0])
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=output_labels)

# %%
#Files
file = '../labeled_dataset/GL55_DN_3A.csv'
columns=['FSC-H', 'SSC-H', 'B530-H', 'B572-H', 'B675-H']
df_labeled = pd.read_csv(file)

#creation of X and y
X,y = split_input_output(df_labeled,target_feature='label')

#Detect and remove outliers
X,y = remove_outliers(X,y,contamination=0.03)

#Standardize our data
scaler = preprocessing.MinMaxScaler(feature_range=(-1,1))
X[X.columns] = scaler.fit_transform(X[X.columns])

#Save file in csv format
save_to_csv(X,y)

# %%
os.system("python ../FlowGrid/sample_code.py --f fc_data.csv --n 4 --eps 1.1")
output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

# %%
#plot_results_b530_b572(X, columns, assignments=output_labels)

# %%
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=y)

# %%
X = X.drop([0])
sns.scatterplot(data=X, x="B530-H", y="B572-H", hue=output_labels)

# %% [markdown]
# ## Automating the clustering and save outputs

# %%
sns_plot.savefig("output.png")

# %% [markdown]
# # Older work without labeled dataset

# %% [markdown]
# ## Clustering without labeled

# %%
fc_data, channels = load_important_data('GL8_UP_1B.fcs','/../data/')

fc_data, tmp = standardize_log(fc_data)
fc_data, indices = remove_outliers_with_indices(fc_data, max_deviation = 4)

fc_subdata_array = np.array(fc_data)
np.savetxt("fc_data.csv", fc_subdata_array, delimiter=",")

os.system("python ../FlowGrid/sample_code.py --f fc_data.csv --n 2 --eps 1.1")

output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

fc_data = np.delete(fc_data, obj=0, axis=0)

plot_results_b530_b572(fc_data, channels, assignments=output_labels)

# %% [markdown]
# ## Density gating

# %%
#fc_data, channels = load_important_data('GL8_UP_1B.fcs')
s = FlowCal.io.FCSData('../data/GL8_UP_1B.fcs')
s = FlowCal.transform.to_rfi(s)
s_g1 = FlowCal.gate.high_low(s, channels=['B530-H','B572-H'])
FlowCal.plot.density2d(s_g1, channels=['B530-H','B572-H'], mode='scatter')
plt.show()

# %%
s_g2 = FlowCal.gate.high_low(s_g1, channels='B530-H', low=25)
FlowCal.plot.density2d(s_g2, channels=['B530-H','B572-H'], mode='scatter')
plt.show()

# %%
s_g4 = FlowCal.gate.density2d(s_g1,channels=['B530-H','B572-H'], gate_fraction=0.75)
FlowCal.plot.density2d(s_g4,channels=['B530-H','B572-H'],mode='scatter')
plt.show()

# %% [markdown]
# ## Other clustering algo without labeled dataset

# %%
fc_data, channels = load_important_data('GL9_DN_1A.fcs','/../data/')

fc_data, tmp = standardize_log(fc_data)
fc_data, indices = remove_outliers_with_indices(fc_data, max_deviation = 4)

fc_subdata_array = np.array(fc_data)
np.savetxt("fc_data.csv", fc_subdata_array, delimiter=",")

os.system("python ../FlowGrid/sample_code.py --f fc_data.csv --n 2 --eps 1.1")

output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

fc_data = np.delete(fc_data, obj=0, axis=0)

plot_results_b530_b572(fc_data, channels, assignments=output_labels)

# %%
s = FlowCal.io.FCSData('../data/GL9_DN_1A.fcs')
s = FlowCal.transform.to_rfi(s)
s_g1 = FlowCal.gate.high_low(s, channels=['B530-H','B572-H'])

s_g4 = FlowCal.gate.density2d(s_g1,channels=['B530-H','B572-H'], gate_fraction=0.75)
FlowCal.plot.density2d(s_g4,channels=['B530-H','B572-H'],mode='scatter')
plt.show()

# %%
fc_data, channels = load_important_data('GL11_UP_2A.fcs','/../data/')

fc_data, tmp = standardize_log(fc_data)
fc_data, indices = remove_outliers_with_indices(fc_data, max_deviation = 4)

fc_subdata_array = np.array(fc_data)
np.savetxt("fc_data.csv", fc_subdata_array, delimiter=",")

os.system("python ../FlowGrid/sample_code.py --f fc_data.csv --n 2 --eps 1.1")

output_labels = np.genfromtxt('fc_data_FlowGrid_label.csv', delimiter=',')

fc_data = np.delete(fc_data, obj=0, axis=0)

plot_results_b530_b572(fc_data, channels, assignments=output_labels)
